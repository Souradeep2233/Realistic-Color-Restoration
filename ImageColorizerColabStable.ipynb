# %%
#NOTE:  This must be the first call in order to work properly!
from deoldify import device
from deoldify.device_id import DeviceId
device.set(device=DeviceId.GPU0)

import torch

if not torch.cuda.is_available():
    print('GPU not available.')

# %%
import fastai
from deoldify.visualize import *

torch.backends.cudnn.benchmark = True

# %%
colorizer = get_image_colorizer(artistic=False)
# Out:
# d:\All-Projects\Realistic Colour Restoration\fastai\data_block.py:451: UserWarning: Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.
#   warn("Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.")
# d:\All-Projects\Realistic Colour Restoration\fastai\data_block.py:453: UserWarning: Your validation set is empty. If this is by design, use `split_none()`
#                  or pass `ignore_empty=True` when labelling to remove this warning.
#   warn("""Your validation set is empty. If this is by design, use `split_none()`
# d:\Anaconda\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...

# %% [markdown]
# #◢ Colorize!!

# %%
show_image_in_notebook("C:\\Users\\soura\\OneDrive\\Desktop\\pexels-photo-2468487.jpeg")

# %% [markdown]
# ## See how well render_factor values perform on the image here

# %%
for i in range(10,20,2):
    colorizer.plot_transformed_image("C:\\Users\\soura\\OneDrive\\Desktop\\pexels-photo-2468487.jpeg", render_factor=i, display_render_factor=True, figsize=(8,8))
